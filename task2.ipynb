# %% [markdown]
# **TASK 2**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **TASK 2A**
# Random Forest and LSTM

# %%
#shift mood by 1 (since we're predicting for the day after)
data = pd.read_csv('ARIMA_imputed_data.csv')
data['mood'] = data['mood'].shift(1)

# %%
data['time'] = pd.to_datetime(data['time'])

# %%
print("Number of unique IDs:", data['id'].nunique())
# Out:
# Number of unique IDs: 27

# %%
#Split train/test - with logical temporal order and perform Random Forest classifier
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report

#FOR RF, CHANGE DATETIME TO DAY OF THE WEEK (RF NOT HANDLING DT OBJECT)
data['day_of_week'] = data['time'].dt.dayofweek
#drop time column
data.drop('time', axis=1, inplace=True)

#drop rows where mood == NaN (can't train on missing values)
data = data.dropna(subset=['mood'])

#1-hot encode ID
encoder = OneHotEncoder()
encoded_ids = encoder.fit_transform(data[['id']]).toarray()
encoded_id_df = pd.DataFrame(encoded_ids, 
                             columns=["id_" + str(i) for i in range(encoded_ids.shape[1])])
data.reset_index(drop=True, inplace=True)
encoded_id_df.reset_index(drop=True, inplace=True)
data = pd.concat([data, encoded_id_df], axis=1)
data.drop('id', axis=1, inplace=True)

#Create bins for the mood (classification)
bins = [0,4,7,10]
labels = ["sad", "neutral", "happy"]
data['mood_category'] = pd.cut(data['mood'], bins=bins, labels=labels, include_lowest=True)
data.drop('mood', axis=1, inplace=True)

#TIME SERIE SPLIT - MAYYBE OTHER TRAIN TEST SPLIT WOULD GIVE BETTER RESULTS
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(data):
    
    train_data, test_data = data.iloc[train_index], data.iloc[test_index]
    
    X_train = train_data.drop('mood_category', axis='columns')
    y_train = train_data['mood_category']


    X_test = test_data.drop('mood_category', axis='columns')
    y_test = test_data['mood_category']
    
    # Train 
    rf = RandomForestClassifier(n_estimators=100, random_state=42)
    rf.fit(X_train, y_train)

    #test
    y_pred = rf.predict(X_test)

    #score
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 38.23%
#               precision    recall  f1-score   support
#
#        happy       0.18      0.56      0.28        68
#      neutral       0.73      0.34      0.47       255
#          sad       0.00      0.00      0.00         4
#
#     accuracy                           0.38       327
#    macro avg       0.30      0.30      0.25       327
# weighted avg       0.61      0.38      0.42       327
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 48.32%
#               precision    recall  f1-score   support
#
#        happy       0.46      0.24      0.31       161
#      neutral       0.49      0.73      0.59       165
#          sad       0.00      0.00      0.00         1
#
#     accuracy                           0.48       327
#    macro avg       0.32      0.32      0.30       327
# weighted avg       0.47      0.48      0.45       327
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 51.68%
#               precision    recall  f1-score   support
#
#        happy       0.34      0.35      0.35       119
#      neutral       0.62      0.61      0.62       208
#
#     accuracy                           0.52       327
#    macro avg       0.48      0.48      0.48       327
# weighted avg       0.52      0.52      0.52       327
#
# Accuracy: 49.85%
#               precision    recall  f1-score   support
#
#        happy       0.59      0.27      0.37       179
#      neutral       0.47      0.77      0.58       148
#
#     accuracy                           0.50       327
#    macro avg       0.53      0.52      0.48       327
# weighted avg       0.53      0.50      0.47       327
#
# Accuracy: 43.12%
#               precision    recall  f1-score   support
#
#        happy       0.71      0.26      0.38       220
#      neutral       0.34      0.78      0.47       107
#
#     accuracy                           0.43       327
#    macro avg       0.52      0.52      0.43       327
# weighted avg       0.59      0.43      0.41       327

# %%
#Perform RNN LSTM
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.metrics import classification_report, accuracy_score

# Data preprocessing
data['day_of_week'] = data['time'].dt.dayofweek
data.drop('time', axis=1, inplace=True)
data = data.dropna(subset=['mood'])  # Ensure no NaNs in mood

# Encode categorical data
encoder = OneHotEncoder()
encoded_ids = encoder.fit_transform(data[['id']]).toarray()
encoded_id_df = pd.DataFrame(encoded_ids, columns=["id_" + str(i) for i in range(encoded_ids.shape[1])])
data = pd.concat([data.reset_index(drop=True), encoded_id_df.reset_index(drop=True)], axis=1)
data.drop('id', axis=1, inplace=True)

# Binning mood for classification
bins = [1, 4, 7, 10]
labels = [0, 1, 2]  # Use numeric labels for to_categorical
data['mood_category'] = pd.cut(data['mood'], bins=bins, labels=labels, include_lowest=True)
data.drop('mood', axis=1, inplace=True)

# Normalize features
scaler = MinMaxScaler()
data[data.columns.difference(['mood_category'])] = scaler.fit_transform(data[data.columns.difference(['mood_category'])])

# Prepare data for LSTM
tscv = TimeSeriesSplit(n_splits=5)
for train_index, test_index in tscv.split(data):
    train_data, test_data = data.iloc[train_index], data.iloc[test_index]
    
    # Assuming here we're just using 'n' days of data directly as features, without additional sequencing.
    X_train = train_data.drop('mood_category', axis=1).values
    y_train = to_categorical(train_data['mood_category'].values)
    X_test = test_data.drop('mood_category', axis=1).values
    y_test = to_categorical(test_data['mood_category'].values)
    
    # Reshape for LSTM [samples, time steps, features]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
    
    # Build LSTM model
    model = Sequential()
    model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))  # Output layer: 3 units for 3 categories
    
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Fit model
    model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=2)
    
    # Predict
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    # Evaluate the model
    #print("Accuracy:", accuracy_score(y_true_classes, y_pred_classes))
    accuracy = accuracy_score(y_true_classes, y_pred_classes)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(classification_report(y_true_classes, y_pred_classes))
# Out:
# Epoch 1/20
# 11/11 - 2s - loss: 1.0451 - accuracy: 0.4848 - val_loss: 1.0436 - val_accuracy: 0.2080 - 2s/epoch - 187ms/step
# Epoch 2/20
# 11/11 - 0s - loss: 0.9898 - accuracy: 0.5394 - val_loss: 1.0099 - val_accuracy: 0.2080 - 64ms/epoch - 6ms/step
# Epoch 3/20
# 11/11 - 0s - loss: 0.9399 - accuracy: 0.5515 - val_loss: 0.9774 - val_accuracy: 0.2080 - 69ms/epoch - 6ms/step
# Epoch 4/20
# 11/11 - 0s - loss: 0.8861 - accuracy: 0.5788 - val_loss: 0.9396 - val_accuracy: 0.2080 - 60ms/epoch - 5ms/step
# Epoch 5/20
# 11/11 - 0s - loss: 0.8501 - accuracy: 0.5636 - val_loss: 0.9192 - val_accuracy: 0.2080 - 59ms/epoch - 5ms/step
# Epoch 6/20
# 11/11 - 0s - loss: 0.8123 - accuracy: 0.5394 - val_loss: 0.8928 - val_accuracy: 0.2080 - 55ms/epoch - 5ms/step
# Epoch 7/20
# 11/11 - 0s - loss: 0.7820 - accuracy: 0.6152 - val_loss: 0.8770 - val_accuracy: 0.2080 - 52ms/epoch - 5ms/step
# Epoch 8/20
# 11/11 - 0s - loss: 0.7673 - accuracy: 0.6061 - val_loss: 0.8461 - val_accuracy: 0.2232 - 56ms/epoch - 5ms/step
# Epoch 9/20
# 11/11 - 0s - loss: 0.7478 - accuracy: 0.6364 - val_loss: 0.8197 - val_accuracy: 0.2263 - 53ms/epoch - 5ms/step
# Epoch 10/20
# 11/11 - 0s - loss: 0.7233 - accuracy: 0.6636 - val_loss: 0.8225 - val_accuracy: 0.2232 - 53ms/epoch - 5ms/step
# Epoch 11/20
# 11/11 - 0s - loss: 0.7106 - accuracy: 0.6273 - val_loss: 0.8293 - val_accuracy: 0.2202 - 58ms/epoch - 5ms/step
# Epoch 12/20
# 11/11 - 0s - loss: 0.6948 - accuracy: 0.6515 - val_loss: 0.8185 - val_accuracy: 0.2232 - 74ms/epoch - 7ms/step
# Epoch 13/20
# 11/11 - 0s - loss: 0.6886 - accuracy: 0.6727 - val_loss: 0.8217 - val_accuracy: 0.2232 - 55ms/epoch - 5ms/step
# Epoch 14/20
# 11/11 - 0s - loss: 0.6885 - accuracy: 0.6515 - val_loss: 0.8213 - val_accuracy: 0.2232 - 52ms/epoch - 5ms/step
# Epoch 15/20
# 11/11 - 0s - loss: 0.6691 - accuracy: 0.6667 - val_loss: 0.8141 - val_accuracy: 0.2263 - 52ms/epoch - 5ms/step
# Epoch 16/20
# 11/11 - 0s - loss: 0.6659 - accuracy: 0.6485 - val_loss: 0.8027 - val_accuracy: 0.2599 - 53ms/epoch - 5ms/step
# Epoch 17/20
# 11/11 - 0s - loss: 0.6523 - accuracy: 0.6818 - val_loss: 0.7968 - val_accuracy: 0.2875 - 61ms/epoch - 6ms/step
# Epoch 18/20
# 11/11 - 0s - loss: 0.6435 - accuracy: 0.7061 - val_loss: 0.8115 - val_accuracy: 0.2385 - 61ms/epoch - 6ms/step
# Epoch 19/20
# 11/11 - 0s - loss: 0.6491 - accuracy: 0.6939 - val_loss: 0.8256 - val_accuracy: 0.2232 - 67ms/epoch - 6ms/step
# Epoch 20/20
# 11/11 - 0s - loss: 0.6301 - accuracy: 0.6758 - val_loss: 0.8171 - val_accuracy: 0.2416 - 64ms/epoch - 6ms/step
# 11/11 [==============================] - 0s 2ms/step
# Accuracy: 24.16%
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.09      0.15       255
#            2       0.19      0.84      0.31        68
#
#     accuracy                           0.24       327
#    macro avg       0.29      0.31      0.16       327
# weighted avg       0.56      0.24      0.18       327
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/20
# 21/21 - 2s - loss: 1.0286 - accuracy: 0.5967 - val_loss: 0.9984 - val_accuracy: 0.5046 - 2s/epoch - 113ms/step
# Epoch 2/20
# 21/21 - 0s - loss: 0.9244 - accuracy: 0.6180 - val_loss: 0.9270 - val_accuracy: 0.5046 - 70ms/epoch - 3ms/step
# Epoch 3/20
# 21/21 - 0s - loss: 0.8418 - accuracy: 0.6195 - val_loss: 0.8698 - val_accuracy: 0.5046 - 83ms/epoch - 4ms/step
# Epoch 4/20
# 21/21 - 0s - loss: 0.7848 - accuracy: 0.6195 - val_loss: 0.8285 - val_accuracy: 0.5046 - 80ms/epoch - 4ms/step
# Epoch 5/20
# 21/21 - 0s - loss: 0.7405 - accuracy: 0.6256 - val_loss: 0.7985 - val_accuracy: 0.5046 - 78ms/epoch - 4ms/step
# Epoch 6/20
# 21/21 - 0s - loss: 0.7113 - accuracy: 0.6484 - val_loss: 0.7853 - val_accuracy: 0.5046 - 67ms/epoch - 3ms/step
# Epoch 7/20
# 21/21 - 0s - loss: 0.6883 - accuracy: 0.6636 - val_loss: 0.7754 - val_accuracy: 0.5046 - 79ms/epoch - 4ms/step
# Epoch 8/20
# 21/21 - 0s - loss: 0.6599 - accuracy: 0.6834 - val_loss: 0.7708 - val_accuracy: 0.5046 - 66ms/epoch - 3ms/step
# Epoch 9/20
# 21/21 - 0s - loss: 0.6477 - accuracy: 0.6895 - val_loss: 0.7715 - val_accuracy: 0.5046 - 65ms/epoch - 3ms/step
# Epoch 10/20
# 21/21 - 0s - loss: 0.6363 - accuracy: 0.7123 - val_loss: 0.7698 - val_accuracy: 0.5046 - 66ms/epoch - 3ms/step
# Epoch 11/20
# 21/21 - 0s - loss: 0.6243 - accuracy: 0.7139 - val_loss: 0.7700 - val_accuracy: 0.5046 - 76ms/epoch - 4ms/step
# Epoch 12/20
# 21/21 - 0s - loss: 0.6157 - accuracy: 0.7169 - val_loss: 0.7745 - val_accuracy: 0.5046 - 69ms/epoch - 3ms/step
# Epoch 13/20
# 21/21 - 0s - loss: 0.6094 - accuracy: 0.7108 - val_loss: 0.7736 - val_accuracy: 0.5046 - 67ms/epoch - 3ms/step
# Epoch 14/20
# 21/21 - 0s - loss: 0.5906 - accuracy: 0.7093 - val_loss: 0.7850 - val_accuracy: 0.5046 - 67ms/epoch - 3ms/step
# Epoch 15/20
# 21/21 - 0s - loss: 0.5873 - accuracy: 0.7291 - val_loss: 0.7781 - val_accuracy: 0.5015 - 67ms/epoch - 3ms/step
# Epoch 16/20
# 21/21 - 0s - loss: 0.5891 - accuracy: 0.7093 - val_loss: 0.7793 - val_accuracy: 0.5046 - 66ms/epoch - 3ms/step
# Epoch 17/20
# 21/21 - 0s - loss: 0.5878 - accuracy: 0.7123 - val_loss: 0.7845 - val_accuracy: 0.5046 - 68ms/epoch - 3ms/step
# Epoch 18/20
# 21/21 - 0s - loss: 0.5686 - accuracy: 0.7017 - val_loss: 0.7844 - val_accuracy: 0.5107 - 75ms/epoch - 4ms/step
# Epoch 19/20
# 21/21 - 0s - loss: 0.5639 - accuracy: 0.7321 - val_loss: 0.7853 - val_accuracy: 0.5076 - 75ms/epoch - 4ms/step
# Epoch 20/20
# 21/21 - 0s - loss: 0.5691 - accuracy: 0.7047 - val_loss: 0.7912 - val_accuracy: 0.5015 - 77ms/epoch - 4ms/step
# 11/11 [==============================] - 0s 2ms/step
# Accuracy: 50.15%
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      0.95      0.66       165
#            2       0.47      0.04      0.08       161
#
#     accuracy                           0.50       327
#    macro avg       0.32      0.33      0.25       327
# weighted avg       0.48      0.50      0.37       327
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/20
# 31/31 - 2s - loss: 1.0166 - accuracy: 0.5081 - val_loss: 0.9239 - val_accuracy: 0.6361 - 2s/epoch - 70ms/step
# Epoch 2/20
# 31/31 - 0s - loss: 0.8552 - accuracy: 0.5925 - val_loss: 0.8053 - val_accuracy: 0.6361 - 84ms/epoch - 3ms/step
# Epoch 3/20
# 31/31 - 0s - loss: 0.7724 - accuracy: 0.5935 - val_loss: 0.7513 - val_accuracy: 0.6361 - 85ms/epoch - 3ms/step
# Epoch 4/20
# 31/31 - 0s - loss: 0.7284 - accuracy: 0.6220 - val_loss: 0.7305 - val_accuracy: 0.6361 - 81ms/epoch - 3ms/step
# Epoch 5/20
# 31/31 - 0s - loss: 0.7006 - accuracy: 0.6484 - val_loss: 0.7209 - val_accuracy: 0.5933 - 83ms/epoch - 3ms/step
# Epoch 6/20
# 31/31 - 0s - loss: 0.6946 - accuracy: 0.6596 - val_loss: 0.7172 - val_accuracy: 0.5780 - 83ms/epoch - 3ms/step
# Epoch 7/20
# 31/31 - 0s - loss: 0.6730 - accuracy: 0.6860 - val_loss: 0.7147 - val_accuracy: 0.5749 - 79ms/epoch - 3ms/step
# Epoch 8/20
# 31/31 - 0s - loss: 0.6488 - accuracy: 0.7033 - val_loss: 0.7182 - val_accuracy: 0.5566 - 75ms/epoch - 2ms/step
# Epoch 9/20
# 31/31 - 0s - loss: 0.6430 - accuracy: 0.7073 - val_loss: 0.7276 - val_accuracy: 0.4648 - 77ms/epoch - 2ms/step
# Epoch 10/20
# 31/31 - 0s - loss: 0.6234 - accuracy: 0.7104 - val_loss: 0.7274 - val_accuracy: 0.4924 - 84ms/epoch - 3ms/step
# Epoch 11/20
# 31/31 - 0s - loss: 0.6098 - accuracy: 0.7175 - val_loss: 0.7314 - val_accuracy: 0.4862 - 81ms/epoch - 3ms/step
# Epoch 12/20
# 31/31 - 0s - loss: 0.6050 - accuracy: 0.7144 - val_loss: 0.7350 - val_accuracy: 0.4985 - 85ms/epoch - 3ms/step
# Epoch 13/20
# 31/31 - 0s - loss: 0.6052 - accuracy: 0.7104 - val_loss: 0.7514 - val_accuracy: 0.4832 - 83ms/epoch - 3ms/step
# Epoch 14/20
# 31/31 - 0s - loss: 0.5975 - accuracy: 0.7185 - val_loss: 0.7580 - val_accuracy: 0.4924 - 82ms/epoch - 3ms/step
# Epoch 15/20
# 31/31 - 0s - loss: 0.5892 - accuracy: 0.6941 - val_loss: 0.7513 - val_accuracy: 0.4954 - 82ms/epoch - 3ms/step
# Epoch 16/20
# 31/31 - 0s - loss: 0.5870 - accuracy: 0.7134 - val_loss: 0.7680 - val_accuracy: 0.4832 - 80ms/epoch - 3ms/step
# Epoch 17/20
# 31/31 - 0s - loss: 0.5846 - accuracy: 0.7287 - val_loss: 0.7720 - val_accuracy: 0.4954 - 76ms/epoch - 2ms/step
# Epoch 18/20
# 31/31 - 0s - loss: 0.5766 - accuracy: 0.7215 - val_loss: 0.7866 - val_accuracy: 0.4801 - 79ms/epoch - 3ms/step
# Epoch 19/20
# 31/31 - 0s - loss: 0.5790 - accuracy: 0.7185 - val_loss: 0.7981 - val_accuracy: 0.4740 - 80ms/epoch - 3ms/step
# Epoch 20/20
# 31/31 - 0s - loss: 0.5742 - accuracy: 0.7205 - val_loss: 0.7919 - val_accuracy: 0.4985 - 83ms/epoch - 3ms/step
# 11/11 [==============================] - 0s 1ms/step
# Accuracy: 49.85%
#               precision    recall  f1-score   support
#
#            1       0.60      0.62      0.61       208
#            2       0.30      0.29      0.29       119
#
#     accuracy                           0.50       327
#    macro avg       0.45      0.45      0.45       327
# weighted avg       0.49      0.50      0.50       327
#
# Epoch 1/20
# 41/41 - 2s - loss: 0.9844 - accuracy: 0.5927 - val_loss: 0.9368 - val_accuracy: 0.4526 - 2s/epoch - 56ms/step
# Epoch 2/20
# 41/41 - 0s - loss: 0.8144 - accuracy: 0.6056 - val_loss: 0.8326 - val_accuracy: 0.4526 - 98ms/epoch - 2ms/step
# Epoch 3/20
# 41/41 - 0s - loss: 0.7394 - accuracy: 0.6148 - val_loss: 0.7803 - val_accuracy: 0.4526 - 94ms/epoch - 2ms/step
# Epoch 4/20
# 41/41 - 0s - loss: 0.7041 - accuracy: 0.6301 - val_loss: 0.7589 - val_accuracy: 0.4526 - 91ms/epoch - 2ms/step
# Epoch 5/20
# 41/41 - 0s - loss: 0.6796 - accuracy: 0.6590 - val_loss: 0.7416 - val_accuracy: 0.4495 - 92ms/epoch - 2ms/step
# Epoch 6/20
# 41/41 - 0s - loss: 0.6581 - accuracy: 0.6758 - val_loss: 0.7377 - val_accuracy: 0.4557 - 91ms/epoch - 2ms/step
# Epoch 7/20
# 41/41 - 0s - loss: 0.6471 - accuracy: 0.6728 - val_loss: 0.7284 - val_accuracy: 0.4495 - 91ms/epoch - 2ms/step
# Epoch 8/20
# 41/41 - 0s - loss: 0.6349 - accuracy: 0.6865 - val_loss: 0.7261 - val_accuracy: 0.4404 - 92ms/epoch - 2ms/step
# Epoch 9/20
# 41/41 - 0s - loss: 0.6257 - accuracy: 0.6873 - val_loss: 0.7210 - val_accuracy: 0.4648 - 92ms/epoch - 2ms/step
# Epoch 10/20
# 41/41 - 0s - loss: 0.6230 - accuracy: 0.6796 - val_loss: 0.7302 - val_accuracy: 0.4495 - 102ms/epoch - 2ms/step
# Epoch 11/20
# 41/41 - 0s - loss: 0.6106 - accuracy: 0.6880 - val_loss: 0.7246 - val_accuracy: 0.4587 - 104ms/epoch - 3ms/step
# Epoch 12/20
# 41/41 - 0s - loss: 0.6048 - accuracy: 0.6911 - val_loss: 0.7356 - val_accuracy: 0.4495 - 102ms/epoch - 2ms/step
# Epoch 13/20
# 41/41 - 0s - loss: 0.6016 - accuracy: 0.6812 - val_loss: 0.7115 - val_accuracy: 0.4862 - 104ms/epoch - 3ms/step
# Epoch 14/20
# 41/41 - 0s - loss: 0.5953 - accuracy: 0.7063 - val_loss: 0.7350 - val_accuracy: 0.4618 - 108ms/epoch - 3ms/step
# Epoch 15/20
# 41/41 - 0s - loss: 0.6025 - accuracy: 0.6903 - val_loss: 0.7263 - val_accuracy: 0.4648 - 105ms/epoch - 3ms/step
# Epoch 16/20
# 41/41 - 0s - loss: 0.5978 - accuracy: 0.6842 - val_loss: 0.7134 - val_accuracy: 0.4893 - 105ms/epoch - 3ms/step
# Epoch 17/20
# 41/41 - 0s - loss: 0.5892 - accuracy: 0.6911 - val_loss: 0.7130 - val_accuracy: 0.4893 - 104ms/epoch - 3ms/step
# Epoch 18/20
# 41/41 - 0s - loss: 0.5793 - accuracy: 0.6873 - val_loss: 0.7223 - val_accuracy: 0.4587 - 103ms/epoch - 3ms/step
# Epoch 19/20
# 41/41 - 0s - loss: 0.5834 - accuracy: 0.7063 - val_loss: 0.7211 - val_accuracy: 0.4557 - 104ms/epoch - 3ms/step
# Epoch 20/20
# 41/41 - 0s - loss: 0.5811 - accuracy: 0.6888 - val_loss: 0.7095 - val_accuracy: 0.5168 - 101ms/epoch - 2ms/step
# 11/11 [==============================] - 0s 1ms/step
# Accuracy: 51.68%
#               precision    recall  f1-score   support
#
#            1       0.48      0.68      0.56       148
#            2       0.59      0.39      0.47       179
#
#     accuracy                           0.52       327
#    macro avg       0.53      0.53      0.51       327
# weighted avg       0.54      0.52      0.51       327
#
# Epoch 1/20
# 52/52 - 2s - loss: 0.9707 - accuracy: 0.5751 - val_loss: 0.9381 - val_accuracy: 0.3272 - 2s/epoch - 45ms/step
# Epoch 2/20
# 52/52 - 0s - loss: 0.7939 - accuracy: 0.6081 - val_loss: 0.8161 - val_accuracy: 0.3272 - 124ms/epoch - 2ms/step
# Epoch 3/20
# 52/52 - 0s - loss: 0.7247 - accuracy: 0.6160 - val_loss: 0.8020 - val_accuracy: 0.3272 - 112ms/epoch - 2ms/step
# Epoch 4/20
# 52/52 - 0s - loss: 0.6891 - accuracy: 0.6520 - val_loss: 0.7760 - val_accuracy: 0.3333 - 110ms/epoch - 2ms/step
# Epoch 5/20
# 52/52 - 0s - loss: 0.6664 - accuracy: 0.6606 - val_loss: 0.7591 - val_accuracy: 0.3792 - 110ms/epoch - 2ms/step
# Epoch 6/20
# 52/52 - 0s - loss: 0.6432 - accuracy: 0.6716 - val_loss: 0.7937 - val_accuracy: 0.3364 - 112ms/epoch - 2ms/step
# Epoch 7/20
# 52/52 - 0s - loss: 0.6379 - accuracy: 0.6630 - val_loss: 0.7877 - val_accuracy: 0.3609 - 118ms/epoch - 2ms/step
# Epoch 8/20
# 52/52 - 0s - loss: 0.6363 - accuracy: 0.6593 - val_loss: 0.8021 - val_accuracy: 0.3700 - 124ms/epoch - 2ms/step
# Epoch 9/20
# 52/52 - 0s - loss: 0.6206 - accuracy: 0.6685 - val_loss: 0.8284 - val_accuracy: 0.3609 - 121ms/epoch - 2ms/step
# Epoch 10/20
# 52/52 - 0s - loss: 0.6154 - accuracy: 0.6832 - val_loss: 0.8690 - val_accuracy: 0.3394 - 118ms/epoch - 2ms/step
# Epoch 11/20
# 52/52 - 0s - loss: 0.6134 - accuracy: 0.6813 - val_loss: 0.8254 - val_accuracy: 0.4037 - 123ms/epoch - 2ms/step
# Epoch 12/20
# 52/52 - 0s - loss: 0.6064 - accuracy: 0.6740 - val_loss: 0.8394 - val_accuracy: 0.4037 - 120ms/epoch - 2ms/step
# Epoch 13/20
# 52/52 - 0s - loss: 0.6009 - accuracy: 0.6825 - val_loss: 0.9045 - val_accuracy: 0.3364 - 120ms/epoch - 2ms/step
# Epoch 14/20
# 52/52 - 0s - loss: 0.6058 - accuracy: 0.6801 - val_loss: 0.8708 - val_accuracy: 0.4067 - 125ms/epoch - 2ms/step
# Epoch 15/20
# 52/52 - 0s - loss: 0.5981 - accuracy: 0.6941 - val_loss: 0.8759 - val_accuracy: 0.4098 - 118ms/epoch - 2ms/step
# Epoch 16/20
# 52/52 - 0s - loss: 0.5977 - accuracy: 0.6764 - val_loss: 0.8837 - val_accuracy: 0.4128 - 121ms/epoch - 2ms/step
# Epoch 17/20
# 52/52 - 0s - loss: 0.5841 - accuracy: 0.6832 - val_loss: 0.8972 - val_accuracy: 0.4098 - 122ms/epoch - 2ms/step
# Epoch 18/20
# 52/52 - 0s - loss: 0.5815 - accuracy: 0.6972 - val_loss: 0.9048 - val_accuracy: 0.4067 - 120ms/epoch - 2ms/step
# Epoch 19/20
# 52/52 - 0s - loss: 0.5833 - accuracy: 0.7045 - val_loss: 0.8610 - val_accuracy: 0.4343 - 126ms/epoch - 2ms/step
# Epoch 20/20
# 52/52 - 0s - loss: 0.5810 - accuracy: 0.6947 - val_loss: 0.9375 - val_accuracy: 0.4006 - 128ms/epoch - 2ms/step
# 11/11 [==============================] - 0s 1ms/step
# Accuracy: 40.06%
#               precision    recall  f1-score   support
#
#            1       0.34      0.90      0.49       107
#            2       0.76      0.16      0.26       220
#
#     accuracy                           0.40       327
#    macro avg       0.55      0.53      0.38       327
# weighted avg       0.62      0.40      0.34       327
